# %% [markdown]
# ## Deep-Learning:
# <pre>
# <h3><i>It is the subset of ML which uses neural network. It is inspried from the structure and function of the neural networks of Human brain</h3>
# <h3><i>It is able to huge amount of data, it can solve complex problem and can autometicaly extract features and patterns from the data</h3>
# <h3><i>In ML training is fast and testing is comparetively slow where as in DL training is very slow and testing is fast</h3>
# </pre>

# %% [markdown]
# ## Artificial Neural Network(ANN)
# ![Alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSjDdZepMKx3DNnySSdPIFK1fq1vv9aEBB23w4UDRUG_PDq_1wdpZnE8f8Q&s=10)

# %%
### X1

# %% [markdown]
# ### B is the bayes value which is allow us to shift the activation fucntion up or down

# %% [markdown]
# ### Activation Fucn: It decides whther the neuro should be activeted or not by calculating the waited sum (x1w1 + x2w2 + ... + xnwn + b) and further adding the bayes to it

# %%
## Activation
