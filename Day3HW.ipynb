# %%
age = int(input('Enter Your Age: '))
# Out:
# Enter Your Age:  23

# %%
if age >= 18:
    print('you are eligible for vote'.title())
elif age < 18 and age > 0:
    print('you are not eligible for vote'.title())
else:
    print('Invalid Input'.title())
# Out:
# You Are Eligible For Vote
