# %%
import numpy as np
import pandas as pd

# %%
#Creating DataFrame
#DataFrame is always created using a dictionary
d = {
    'Name': ['Ram', 'Sita', 'Gita', 'Hari', 'Shyam'],
    'Roll': [111, 222, 333, 444, 555],
    'Course': ['AIML', 'Python', 'AIML', 'C', 'JAVA']
    }
d
# Out:
# {'Name': ['Ram', 'Sita', 'Gita', 'Hari', 'Shyam'],
#  'Roll': [111, 222, 333, 444, 555],
#  'Course': ['AIML', 'Python', 'AIML', 'C', 'JAVA']}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#     Name  Roll  Course
# 0    Ram   111    AIML
# 1   Sita   222  Python
# 2   Gita   333    AIML
# 3   Hari   444       C
# 4  Shyam   555    JAVA

# %%
df[2]
# Out:
# --------------------------------------------------------------------------
# KeyError                                 Traceback (most recent call last)
# File C:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 df[2]
#
# ...

# %%
#indexing
df.Name[2]
# Out:
# 'Gita'

# %%
df.Course[0]
# Out:
# 'AIML'

# %%
#slicing
#iloc - used for slicing on DataFrame
#Syntax - df.iloc[row_index, col_index]
df.iloc[::, ::]
# Out:
#     Name  Roll  Course
# 0    Ram   111    AIML
# 1   Sita   222  Python
# 2   Gita   333    AIML
# 3   Hari   444       C
# 4  Shyam   555    JAVA

# %%
df.iloc[1, ::]
# Out:
# Name        Sita
# Roll         222
# Course    Python
# Name: 1, dtype: object

# %%
df.iloc[::, 2]
# Out:
# 0      AIML
# 1    Python
# 2      AIML
# 3         C
# 4      JAVA
# Name: Course, dtype: object

# %%
df.iloc[::2, ::]
# Out:
#     Name  Roll Course
# 0    Ram   111   AIML
# 2   Gita   333   AIML
# 4  Shyam   555   JAVA

# %%
df.iloc[1::2, ::]
# Out:
#    Name  Roll  Course
# 1  Sita   222  Python
# 3  Hari   444       C

# %%
df.iloc[1::2, ::2]
# Out:
#    Name  Course
# 1  Sita  Python
# 3  Hari       C

# %%
# head - it represent the top rows head() - bydefault 5 rows
df.head(3)
# Out:
#    Name  Roll  Course
# 0   Ram   111    AIML
# 1  Sita   222  Python
# 2  Gita   333    AIML

# %%
# tail - it represent bottom rows
df.tail(3)
# Out:
#     Name  Roll Course
# 2   Gita   333   AIML
# 3   Hari   444      C
# 4  Shyam   555   JAVA

# %%
# sample() - it returns random sample from the rows
df.sample()
# Out:
#    Name  Roll  Course
# 1  Sita   222  Python

# %%
df.sample(3)
# Out:
#    Name  Roll  Course
# 0   Ram   111    AIML
# 3  Hari   444       C
# 1  Sita   222  Python

# %%
df = df.rename(columns={'Name': 'Student_Name'})
df
# Out:
#   Student_Name  Roll  Course
# 0          Ram   111    AIML
# 1         Sita   222  Python
# 2         Gita   333    AIML
# 3         Hari   444       C
# 4        Shyam   555    JAVA

# %%
df.set_index('Roll')
# Out:
#      Student_Name  Course
# Roll
# 111           Ram    AIML
# 222          Sita  Python
# 333          Gita    AIML
# 444          Hari       C
# 555         Shyam    JAVA

# %%
# set_index - csn set any col as index position
# df = df.set_index('Roll')
# df.set_index('Roll', inplace=True)
df.set_index('Roll', inplace=True)

# %%
df
# Out:
#      Student_Name  Course
# Roll
# 111           Ram    AIML
# 222          Sita  Python
# 333          Gita    AIML
# 444          Hari       C
# 555         Shyam    JAVA

# %%
df = df.reset_index()

# %%
df
# Out:
#      Student_Name  Course
# Roll
# 111           Ram    AIML
# 222          Sita  Python
# 333          Gita    AIML
# 444          Hari       C
# 555         Shyam    JAVA

# %%
df.Course[333]
# Out:
# 'AIML'

# %%
df = pd.DataFrame({
    'Days': [1,2,3,4,5],
    'Places': ['Puri', 'Mathura', 'Asansol', 'Manali', 'Kolkata'],
    'Visitors': [5895, 5600, 48]
})
