# %%
a='Apple'
a[1:3:1]
# Out:
# 'pp'

# %%
a[1:3:]
# Out:
# 'pp'

# %%
a[4:2:-1] #backward slicing
# Out:
# 'el'

# %%
b = 'Welcome to CTTC'

# %%
b[13:0:-4]
# Out:
# 'Tome'

# %%
b.capitalize()
# Out:
# 'Welcome to cttc'

# %%
b.upper()
# Out:
# 'WELCOME TO CTTC'

# %%
b.lower()
# Out:
# 'welcome to cttc'

# %%
b.title()
# Out:
# 'Welcome To Cttc'

# %%
b.swapcase()
# Out:
# 'wELCOME TO cttc'

# %%
b.casefold()
# Out:
# 'welcome to cttc'

# %%
'σ'.casefold()
# Out:
# 'σ'

# %%
b.center(20)
# Out:
# '  Welcome to CTTC   '

# %%
b.center(20,'_')
# Out:
# '__Welcome to CTTC___'

# %%
"Apple".center(10, '🍎')
# Out:
# '🍎🍎Apple🍎🍎🍎'

# %%
'__Welcome to CTTC___'.strip()
# Out:
# '__Welcome to CTTC___'

# %%
'  Welcome to CTTC   '.strip()
# Out:
# 'Welcome to CTTC'

# %%
'__Welcome _to CTTC___'.strip('_')
# Out:
# 'Welcome _to CTTC'

# %%
'__Welcome _to CTTC___'.rstrip('_')
# Out:
# '__Welcome _to CTTC'

# %%
'__Welcome _to CTTC___'.lstrip('_')
# Out:
# 'Welcome _to CTTC___'

# %%
b.index('C')
# Out:
# 11

# %%
b.count('C')
# Out:
# 2

# %%
b.find('C')
# Out:
# 11

# %%
'@'.join(['username', 'gmail.com'])
# Out:
# 'username@gmail.com'

# %%
'.'.join(['www', 'cttc', 'gov', 'in'])
# Out:
# 'www.cttc.gov.in'

# %%
'Hello Everyone'.split()
# Out:
# ['Hello', 'Everyone']

# %%
'www.cttc.gov.in'.split('.')
# Out:
# ['www', 'cttc', 'gov', 'in']

# %%
'abcdefgh'.isalpha()
# Out:
# True

# %%
'7979'.isalpha()
# Out:
# False

# %%
'7979'.isnumeric()
# Out:
# True

# %%
'7979abc'.isalnum()
# Out:
# True

# %%
'abc'.islower()
# Out:
# True

# %%
'abc'.isupper()
# Out:
# False

# %% [markdown]
# ## List

# %%
l = [45, 63.5, True, 'False']

# %%
l
# Out:
# [45, 63.5, True, 'False']

# %%
l[2]
# Out:
# True

# %%
l[1:3:1]
# Out:
# [63.5, True]

# %% [markdown]
# # List Attributes

# %%
l.append(45)

# %%
l
# Out:
# [45, 63.5, True, 'False', 45]

# %%
l.insert(3,27)

# %%
l
# Out:
# [45, 63.5, True, 27, 'False', 45]

# %%
l.extend([12.5, 'abc'])

# %%
l
# Out:
# [45, 63.5, True, 27, 'False', 45, 12.5, 'abc']

# %%
m = [56, 29.5]
m.extend(l)
m
# Out:
# [56, 29.5, 45, 63.5, True, 27, 'False', 45, 12.5, 'abc']

# %%
l.count(45)
# Out:
# 2

# %%
m.pop()
m
# Out:
# [56, 29.5, 45, 63.5, True, 27, 'False', 45, 12.5]

# %%
m.remove(45)

# %%
m
# Out:
# [56, 29.5, 63.5, True, 27, 'False', 45, 12.5]

# %%
m.clear()
m
# Out:
# []

# %%
l.sort()

# %%
l.remove('False')

# %%
l.sort()

# %%
l
# Out:
# [True, 12.5, 27, 45, 45, 63.5]

# %%
c = [45, 63.5, True, 27, 78, 45, 12.5]

# %%
c.sort(reverse=True)

# %%
c
# Out:
# [78, 63.5, 45, 45, 27, 12.5, True]

# %% [markdown]
# # Tupple Attrubutes

# %%
t = (78, 63.5, 45, 45, 27, 12)
t
# Out:
# (78, 63.5, 45, 45, 27, 12)

# %%
type(t)
# Out:
# tuple

# %%
t[4]
# Out:
# 27

# %%
t[0:6:2]
# Out:
# (78, 45, 27)

# %%
t.
