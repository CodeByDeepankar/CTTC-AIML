# %% [markdown]
# ### NumPy- py library which is used to perform diff mathmetical operations on arrays.

# %%
# to import numpy
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'

# %%
# creating 1D array
# list to array
a = np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a = np.array([1, 2.3, 3, 4, 5, False])
a
# Out:
# array([1. , 2.3, 3. , 4. , 5. , 0. ])

# %%
a = np.array([24,'dog',False,4.6])
a
# Out:
# array(['24', 'dog', 'False', '4.6'], dtype='<U32')

# %%
a = np.array(['cat', 'bat', '2.5'])
a
# Out:
# array(['cat', 'bat', '2.5'], dtype='<U3')

# %%
a = np.array([25, 2.5, True])
print(a)
# Out:
# [25.   2.5  1. ]

# %%
t = np.array((10, 20, 30, 40, 50))
t
# Out:
# array([10, 20, 30, 40, 50])

# %%
s = np.array({1,1,1,2,2,4,4,3,3,3})
s
# Out:
# array({1, 2, 3, 4}, dtype=object)

# %%
d = np.array({'a':1, 'b':2, 'c':3}) #dictonary to array
d
# Out:
# array({'a': 1, 'b': 2, 'c': 3}, dtype=object)
