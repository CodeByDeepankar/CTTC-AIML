# %% [markdown]
# ## wap to count a number of digits and alphabets present inside in entered string

# %%
s = input('Enter a string with digits: ')
a = 0
d = 0
for i in s:
    if i.isdigit():
        d+=1
    elif i.isalpha():
        a+=1
print('Number of digits: ', d)
print('Number of alphabets: ', a)
# Out:
# Enter a string with digits:  deepankar432
# Number of digits:  3
# Number of alphabets:  9

# %% [markdown]
# ### Jump statements (break, continue)

# %%
for i in 'Deepankar':
    if i == 'p':
        break
    print(i)
# Out:
# D
# e
# e

# %%
 ### Continur Statement: the continue keyword return control of the iteration to the beginning of the python for loop or python while loop. All remaining lines int the prevailing iteration of the loop are skipped by the continue keyword, which return execut
