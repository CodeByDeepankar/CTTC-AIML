# %% [markdown]
# # NaiveBayes

# %% [markdown]
# ### Gaussian NB (Both Numeric and Text)
# ### Multinomial NB (For text data only)
# ### Bernouli NB (For Categorical data only)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
